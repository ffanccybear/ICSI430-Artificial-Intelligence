# %% [markdown]
# <img width=300 height=300 src="vacuum.webp">

# %% [markdown]
# ## CS 470 Artificial Intelligence hw1
#
# You are to edit the file hw1.py, as described in the instructions.
# We have provided a solution file, hw1a.pyc, which is compiled bytecode that you may run.
#
# Below we demonstrate the code, both with and without graphics.

# %%
from hw1 import *

# %%
gv = GraphicVacuumEnvironment(10,10,bias=0.5,color={'Agent': (200,0,0), 'Dirt': (230, 115, 40), 'Wall': (100,100,100)})

# %%
rv = TraceAgent(BetterReflexVacuumAgent())
gv.add_thing(rv)
gv.get_world()
# Out:
# [[[<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>]],
#  [[<Wall>], [<Agent>], [], [<Dirt>], [], [], [], [<Dirt>], [<Dirt>], [<Wall>]],
#  [[<Wall>],
#   [<Dirt>],
#   [],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [],
#   [<Wall>]],
#  [[<Wall>],
#   [],
#   [],
#   [<Dirt>],
#   [<Dirt>],
#   [],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Wall>]],
#  [[<Wall>], [], [], [], [], [<Dirt>], [<Dirt>], [<Dirt>], [<Dirt>], [<Wall>]],
#  [[<Wall>], [<Dirt>], [<Dirt>], [], [], [], [<Dirt>], [], [], [<Wall>]],
#  [[<Wall>], [], [<Dirt>], [], [], [], [<Dirt>], [], [], [<Wall>]],
#  [[<Wall>],
#   [],
#   [],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [],
#   [<Dirt>],
#   [<Dirt>],
#   [<Wall>]],
#  [[<Wall>],
#   [],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [],
#   [],
#   [<Dirt>],
#   [<Dirt>],
#   [<Wall>]],
#  [[<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>]]]

# %%
rv.performance
# Out:
# 0

# %%
rv.location
# Out:
# (1, 1)

# %%
gv.run(10)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks87bd1db6-f7ae-4049-86f4-955ab1068214 td {border: 1px solid white;}</style><table id="blocks87bd1db6-f7ae-4049-86f4-955ab1068214" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height ...
# <Agent> perceives ('Clean', 'None') and does Right at (1, 1)
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks3599520c-cd0a-432b-b3f0-d8afae4ddbcb td {border: 1px solid white;}</style><table id="blocks3599520c-cd0a-432b-b3f0-d8afae4ddbcb" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px; heig ...
# <Agent> perceives ('Dirty', 'None') and does Suck at (2, 1)
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksc0d7c3dd-5f73-4653-b734-fc8a1a29c5e1 td {border: 1px solid white;}</style><table id="blocksc0d7c3dd-5f73-4653-b734-fc8a1a29c5e1" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px; heig ...
# <Agent> perceives ('Clean', 'None') and does Right at (2, 1)
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks8fd8bc90-5a81-495e-b68d-2482b09b619b td {border: 1px solid white;}</style><table id="blocks8fd8bc90-5a81-495e-b68d-2482b09b619b" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px; heig ...
# <Agent> perceives ('Clean', 'None') and does Right at (3, 1)
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks4e3504e7-5479-457b-8b52-a0e7413d7a46 td {border: 1px solid white;}</style><table id="blocks4e3504e7-5479-457b-8b52-a0e7413d7a46" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px; heig ...
# <Agent> perceives ('Clean', 'None') and does Right at (4, 1)
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksd0cad9c3-4a2c-48b0-99c4-e96ea78cdde5 td {border: 1px solid white;}</style><table id="blocksd0cad9c3-4a2c-48b0-99c4-e96ea78cdde5" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 5]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px; he ...
# <Agent> perceives ('Dirty', 'None') and does Suck at (5, 1)
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks97b9f498-7f39-45da-8ee8-a977f0a00006 td {border: 1px solid white;}</style><table id="blocks97b9f498-7f39-45da-8ee8-a977f0a00006" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 5]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px; he ...
# <Agent> perceives ('Clean', 'None') and does Up at (5, 1)
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks77301409-f074-41ad-a91f-d941ecb517e8 td {border: 1px solid white;}</style><table id="blocks77301409-f074-41ad-a91f-d941ecb517e8" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 5]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px; he ...
# <Agent> perceives ('Clean', 'None') and does Down at (5, 1)
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks6f3d8f12-54a0-4d2f-af5a-584ff1df45ad td {border: 1px solid white;}</style><table id="blocks6f3d8f12-54a0-4d2f-af5a-584ff1df45ad" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 5]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px;  ...
# <Agent> perceives ('Dirty', 'None') and does Suck at (5, 2)
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks14740add-b057-46d9-88ae-48702d5fc905 td {border: 1px solid white;}</style><table id="blocks14740add-b057-46d9-88ae-48702d5fc905" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 5]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px;  ...
# <Agent> perceives ('Clean', 'None') and does Up at (5, 2)
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks2c009b72-86bf-4942-9be2-90f484493902 td {border: 1px solid white;}</style><table id="blocks2c009b72-86bf-4942-9be2-90f484493902" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 5]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px;  ...

# %%
rv.location
# Out:
# (5, 1)

# %%
rv.performance
# Out:
# 23

# %% [markdown]
# Now we create a vacuum world without graphics.

# %%
nve = NewVacuumEnvironment(10,10,bias=0.5)

# %%
nrv = TraceAgent(BetterReflexVacuumAgent())
nve.add_thing(nrv)
nve.get_world()
# Out:
# [[[<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>]],
#  [[<Wall>],
#   [<Dirt>, <Agent>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [],
#   [],
#   [<Dirt>],
#   [<Dirt>],
#   [<Wall>]],
#  [[<Wall>], [<Dirt>], [], [], [<Dirt>], [], [], [<Dirt>], [], [<Wall>]],
#  [[<Wall>], [], [], [<Dirt>], [], [<Dirt>], [<Dirt>], [], [], [<Wall>]],
#  [[<Wall>], [], [<Dirt>], [], [], [], [<Dirt>], [<Dirt>], [<Dirt>], [<Wall>]],
#  [[<Wall>],
#   [],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [],
#   [<Dirt>],
#   [<Dirt>],
#   [],
#   [<Wall>]],
#  [[<Wall>], [], [], [], [], [<Dirt>], [<Dirt>], [], [], [<Wall>]],
#  [[<Wall>], [], [], [], [], [], [], [<Dirt>], [], [<Wall>]],
#  [[<Wall>], [<Dirt>], [], [<Dirt>], [], [<Dirt>], [], [<Dirt>], [], [<Wall>]],
#  [[<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>]]]

# %%
nve.run(10)
# Out:
# <Agent> perceives ('Dirty', 'None') and does Suck at (1, 1)
# <Agent> perceives ('Clean', 'None') and does Up at (1, 1)
# <Agent> perceives ('Clean', 'None') and does Down at (1, 1)
# <Agent> perceives ('Dirty', 'None') and does Suck at (1, 2)
# <Agent> perceives ('Clean', 'None') and does Up at (1, 2)
# <Agent> perceives ('Clean', 'None') and does Left at (1, 1)
# <Agent> perceives ('Clean', 'None') and does Right at (1, 1)
# <Agent> perceives ('Dirty', 'None') and does Suck at (2, 1)
# <Agent> perceives ('Clean', 'None') and does Down at (2, 1)
# <Agent> perceives ('Clean', 'None') and does Up at (2, 2)

# %%
nrv.location
# Out:
# (2, 1)

# %%
nrv.performance
# Out:
# 23

# %%
main()
# Out:
# hours
# # is it greater than 0?
#  OK  got: 2 expected: <function main.<locals>.<lambda> at 0x7fc32822fcb0>
# NewVacuumEnvironment - Walls
#  OK  got: '[[[<Wall>], [<Wall>], [<Wall>], [<Wall>], [<Wall>]], [[<Wall>], [], [], [], [<Wall>]], [[<Wall>], [], [], [], [<Wall>]], [[<Wall>], [], [], [], [<Wall>]], [[<Wall>], [<Wall>], [<Wall>], [<Wall>], [<Wall>]]]' expected: '[[[<Wall>], [<Wall>], [<Wall>], [<Wall>], [<Wall>]], [[<Wall>], [], [], [], [<Wall>]], [[<Wall>], [], [], [], [<Wall>]], [[<Wall>], [], [], [], [<Wall>]], [[<Wall>], [<Wall>], [<Wall>], [<Wall>], [<Wall>]]]'
# NewVacuumEnvironment - Dirt
#  OK  got: 159 expected: <function main.<locals>.<lambda> at 0x7fc328232170>
# NewVacuumEnvironment - Very Clean
#  OK  got: 0 expected: 0
# NewVacuumEnvironment - Very Dirty
#  OK  got: 324 expected: 324
# TraceAgent and BetterReflexVacuumAgent
# <Agent> perceives ('Dirty', 'None') and does Suck at (1, 1)
#  OK  got: (1, 1) expected: (1, 1)
#  OK  got: 10 expected: 10
# <Agent> perceives ('Clean', 'None') and does Left at (1, 1)
# <Agent> perceives ('Clean', 'None') and does Up at (1, 1)
# <Agent> perceives ('Clean', 'None') and does Down at (1, 1)
# <Agent> perceives ('Dirty', 'None') and does Suck at (1, 2)
# <Agent> perceives ('Clean', 'None') and does Down at (1, 2)
# <Agent> perceives ('Dirty', 'None') and does Suck at (1, 3)
# <Agent> perceives ('Clean', 'None') and does Down at (1, 3)
# <Agent> perceives ('Dirty', 'None') and does Suck at (1, 4)
# <Agent> perceives ('Clean', 'None') and does Up at (1, 4)
# <Agent> perceives ('Clean', 'None') and does Up at (1, 3)
# <Agent> perceives ('Clean', 'None') and does Up at (1, 2)
# <Agent> perceives ('Clean', 'None') and does Left at (1, 1)
# <Agent> perceives ('Clean', 'None') and does Left at (1, 1)
# <Agent> perceives ('Clean', 'None') and does Left at (1, 1)
# <Agent> perceives ('Clean', 'None') and does Right at (1, 1)
# <Agent> perceives ('Dirty', 'None') and does Suck at (2, 1)
# <Agent> perceives ('Clean', 'None') and does Up at (2, 1)
# <Agent> perceives ('Clean', 'None') and does Down at (2, 1)
# <Agent> perceives ('Dirty', 'None') and does Suck at (2, 2)
# <Agent> perceives ('Clean', 'None') and does Down at (2, 2)
#  OK  got: 45 expected: <function main.<locals>.<lambda> at 0x7fc328242a70>

# %% [markdown]
# Below we demonstrate the testing code from the end of agents.py

# %%
environment = TrivialVacuumEnvironment

# %%
agents = [ModelBasedVacuumAgent, ReflexVacuumAgent]

# %%
result = compare_agents(environment, agents)

# %%
result
# Out:
# [(<function agents.ModelBasedVacuumAgent()>, 9),
#  (<function agents.ReflexVacuumAgent()>, -989)]
